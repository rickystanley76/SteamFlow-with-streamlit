# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset as dataframe to work with
df=pd.read_csv('papermil_water_flow.csv')

# %%
df.dtypes
# Out:
# starch_mixing_tank23top_ply                float64
# pulp_to_mixing_tank23                      float64
# power_power_station24                      float64
# starch_mixing_tank23top_ply2               float64
# recycled_liquid_top_ply                    float64
# sum_bleached_pulp                          float64
# flow_after_machine_chest21                 float64
# steam_pressure_group1                      float64
# steam_pressure_group2                      float64
# level_condensate_bucket1                   float64
# level_condensate_bucket1_valve_position    float64
# level_condensate_bucket2_valve_position    float64
# steam_group3_pressure                      float64
# steam_group4under_pressure                 float64
# steam_pressure4_over                       float64
# pressure_yankee_cylinder                   float64
# steam_group5under_pressure                 float64
# steam_pressure5_over                       float64
# pressure_condensate_bucket2                float64
# pressure_condensate_bucket5                float64
# production_paper_machine2                  float64
# dry_production_vira                        float64
# total_starch_paper_machine2                float64
# steamflow                                  float64
# dtype: object

# %%
df.shape
# Out:
# (3491, 24)

# %%
df.describe()
# Out:
#        starch_mixing_tank23top_ply  pulp_to_mixing_tank23  \
# count                  3491.000000            3491.000000
# mean                     33.466978             174.558980
# std                       5.211372              21.726282
# min                      21.055000             130.830000
# 25%                      29.116000             159.775000
# 50%                      33.464000             175.430000
# 75%                      37.643500             191.270000
# max                      60.608000             222.510000
#
#        power_power_station24  starch_mixing_tank23top_ply2  \
# count            3491.000000                   3491.000000
# mean              249.439395                     33.470904
# std                35.629560                      5.211134
# min                12.828000                     21.055000
# 25%               217.620000                     29.116000
# 50%               240.560000                     33.470000
# 75%               277.770000                     37.655000
# max               341.700000                     60.608000
#
#        recycled_liquid_top_ply  sum_bleached_pulp  flow_after_machine_chest21  \
# count              3491.000000        3491.000000                 3491.000000
# mean                  1.388876           7.355975                 2887.792237
# std                   0.187454           0.877126                  365.226054
# min                   0.974720           5.125900                 2147.600000
# 25%                   1.223300           6.740550                 2639.000000
# 50%                   1.381300           7.364000                 2902.100000
# 75%                   1.539300           8.035800                 3168.750000
# max                   1.911000           9.614300                 3699.900000
#
#        steam_pressure_group1  steam_pressure_group2  level_condensate_bucket1  \
# count            3491.000000            3491.000000               3491.000000
# mean               80.831842             156.616677                329.129734
# std                17.877288              18.871034                 26.750133
# min                 5.947500              38.748000                248.200000
# 25%                70.967000             148.785000                322.390000
# 50%                84.104000             166.680000                325.120000
# 75%                97.682000             169.930000                327.830000
# max               103.540000             175.550000                530.960000
#
#        ...  steam_pressure4_over  pressure_yankee_cylinder  \
# count  ...           3491.000000               3491.000000
# mean   ...            237.004841                236.999768
# std    ...             21.401232                 21.414796
# min    ...            141.940000                142.730000
# 25%    ...            224.775000                224.810000
# 50%    ...            241.340000                241.330000
# 75%    ...            252.100000                252.145000
# max    ...            293.320000                294.310000
#
#        steam_group5under_pressure  steam_pressure5_over  \
# count                 3491.000000           3491.000000
# mean                   236.999837            236.985013
# std                     21.334429             21.364826
# min                    142.840000            143.160000
# 25%                    224.915000            224.890000
# 50%                    241.410000            241.390000
# 75%                    252.075000            252.005000
# max                    286.470000            289.870000
#
#        pressure_condensate_bucket2  pressure_condensate_bucket5  \
# count                  3491.000000                  3491.000000
# mean                    158.111687                    75.160020
# std                      21.658085                    17.598555
# min                      38.800000                     2.500000
# 25%                     148.750000                    65.500000
# 50%                     167.360000                    78.510000
# 75%                     173.750000                    90.625000
# max                     187.880000                    99.688000
#
#        production_paper_machine2  dry_production_vira  \
# count                3491.000000          3491.000000
# mean                   11.118898           159.916113
# std                     0.878348            20.332352
# min                     0.000000           115.840000
# 25%                    10.451000           147.010000
# 50%                    11.119000           160.930000
# 75%                    11.855000           175.450000
# max                    13.174000           204.570000
#
#        total_starch_paper_machine2    steamflow
# count                  3491.000000  3491.000000
# mean                     57.512298    18.338152
# std                       6.338158     1.329906
# min                      37.371000    12.920000
# 25%                      52.638500    17.584000
# 50%                      58.515000    18.480000
# 75%                      61.677500    19.126500
# max                      94.887000    23.649000
#
# [8 rows x 24 columns]

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr(method='pearson')
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#Correlation with output variable
cor_target = abs(corrmat["steamflow"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.01]
relevant_features
# Out:
# starch_mixing_tank23top_ply                0.493052
# pulp_to_mixing_tank23                      0.508953
# power_power_station24                      0.400043
# starch_mixing_tank23top_ply2               0.492653
# recycled_liquid_top_ply                    0.438050
# sum_bleached_pulp                          0.468917
# flow_after_machine_chest21                 0.506810
# steam_pressure_group1                      0.483349
# steam_pressure_group2                      0.420019
# level_condensate_bucket1                   0.435678
# level_condensate_bucket1_valve_position    0.635961
# level_condensate_bucket2_valve_position    0.464426
# steam_group3_pressure                      0.540949
# steam_group4under_pressure                 0.547853
# steam_pressure4_over                       0.547464
# pressure_yankee_cylinder                   0.548724
# steam_group5under_pressure                 0.548878
# steam_pressure5_over                       0.547301
# pressure_condensate_bucket2                0.150321
# pressure_condensate_bucket5                0.501262
# production_paper_machine2                  0.524228
# dry_production_vira                        0.581135
# total_starch_paper_machine2                0.455004
# steamflow                                  1.000000
# Name: steamflow, dtype: float64
